# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

# Reading the CSV file
file_path = '/content/drive/MyDrive/Housing.csv'
df = pd.read_csv(file_path)

# Displaying the first few rows of the dataset
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Displaying basic information about the dataset
print("Dataset information:")
print(df.info())
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB
# None

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# Visualizing data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['area'], bins=20, color='lightpink', edgecolor='black')
plt.title('Histogram of a Numerical Column')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##Scatter plot

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['price'], df['area'], alpha=0.5, color='blue')
plt.title('Scatter Plot of Two Numerical Columns')
plt.xlabel('house price on area')
plt.ylabel('house price based on bedromms')
plt.show()

# %% [markdown]
# ##Scatter Plot with Seaborn

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='area', y='price', data=df, alpha=0.5, color='green')
plt.title('Scatter Plot of Two Numerical Columns (Seaborn)')
plt.xlabel('house prediction various on area')
plt.ylabel('house prediction various on price')
plt.show()

# %% [markdown]
# ### **Univariate Regression**

# %%
x_data = df['area']
y_data = df['price']

# %%
x_data
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
# Create each single feature as a vector
x_data = np.array(x_data).reshape((-1,1))
print(x_data)
# Out:
# [[ 7420]
#  [ 8960]
#  [ 9960]
#  [ 7500]
#  [ 7420]
#  [ 7500]
#  [ 8580]
#  [16200]
#  [ 8100]
#  [ 5750]
#  [13200]
#  [ 6000]
#  [ 6550]
#  [ 3500]
#  [ 7800]
#  [ 6000]
#  [ 6600]
#  [ 8500]
#  [ 4600]
#  [ 6420]
#  [ 4320]
#  [ 7155]
#  [ 8050]
#  [ 4560]
#  [ 8800]
#  [ 6540]
#  [ 6000]
#  [ 8875]
#  [ 7950]
#  [ 5500]
#  [ 7475]
#  [ 7000]
#  [ 4880]
#  [ 5960]
#  [ 6840]
#  [ 7000]
#  [ 7482]
#  [ 9000]
#  [ 6000]
#  [ 6000]
#  [ 6550]
#  [ 6360]
#  [ 6480]
#  [ 6000]
#  [ 6000]
#  [ 6000]
#  [ 6000]
#  [ 6600]
#  [ 4300]
#  [ 7440]
#  [ 7440]
#  [ 6325]
#  [ 6000]
#  [ 5150]
#  [ 6000]
#  [ 6000]
#  [11440]
#  [ 9000]
#  [ 7680]
#  [ 6000]
#  [ 6000]
#  [ 8880]
#  [ 6240]
#  [ 6360]
#  [11175]
#  [ 8880]
#  [13200]
#  [ 7700]
#  [ 6000]
#  [12090]
#  [ 4000]
#  [ 6000]
#  [ 5020]
#  [ 6600]
#  [ 4040]
#  [ 4260]
#  [ 6420]
#  [ 6500]
#  [ 5700]
#  [ 6000]
#  [ 6000]
#  [ 4000]
#  [10500]
#  [ 6000]
#  [ 3760]
#  [ 8250]
#  [ 6670]
#  [ 3960]
#  [ 7410]
#  [ 8580]
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.15, random_state=1)


print("shape of training samples:",x_train.shape)
print("shape of test samples :", x_test.shape)
print("shape of train labels :", y_train.shape)
print("shape of test labels:",y_test.shape)
# Out:
# shape of training samples: (463, 1)
# shape of test samples : (82, 1)
# shape of train labels : (463,)
# shape of test labels: (82,)

# %%
from sklearn.linear_model import LinearRegression

from numpy.ma.core import nonzero
lre=LinearRegression()

lre.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Intercept is ",lre.intercept_,"\n","Coef is",lre.coef_)
# Out:
# Intercept is  2530925.3985450496
#  Coef is [434.16276365]

# %%
r_sq = lre.score(x_test, y_test)
print("R Square value is ",r_sq)
# Out:
# R Square value is  0.33031958842137554

# %%
y_pred = lre.predict(x_test)
print(f"predicted response:\n{y_pred}")
# Out:
# predicted response:
# [5240101.04370917 6177892.61318906 7089634.41685006 5318250.34116583
#  5402912.08007721 4093911.3476782  3937612.75276488 5396399.63862249
#  3703164.86039491 4701739.21678553 3681456.7222125  4604052.59496471
#  4614906.66405591 4137327.62404301 5873978.67863539 5752413.10481392
#  4389142.0269589  5135901.98043363 5396399.63862249 4115185.32309695
#  4015762.05022154 4918820.59860958 4106936.23058764 3911562.986946
#  4093911.3476782  6177892.61318906 3833413.68948934 6386290.73974014
#  5027361.2895216  3462204.52657022 5292200.57534694 5363837.43134888
#  3377542.78765884 5070777.56588641 6165736.05580691 3776972.53021509
#  4697397.58914905 3696218.25617654 4788571.76951515 5275268.22756467
#  4684372.70623961 4041811.81604042 3924587.86985544 4680031.07860313
#  5500598.70189803 4419533.42041427 5070777.56588641 4445583.18623315
#  3616332.30766529 4202452.03859022 3911562.986946   3903748.05720033
# ...

# %%
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y_test, y_pred)
RMSE = mean_squared_error(y_test, y_pred, squared=False)
print("MSE is:", MSE)
print("RMSE is:", RMSE)
print("R_squared is:", r_sq)
# Out:
# MSE is: 2760036756476.5703
# RMSE is: 1661335.834946255
# R_squared is: 0.33031958842137554

# %% [markdown]
# ## **MultiVariate Regression**

# %%
x_data = df[[ 'bedrooms','bathrooms','area']]
y_data = df['price']

# %%
x_data.head()
# Out:
#    bedrooms  bathrooms  area
# 0         4          2  7420
# 1         4          4  8960
# 2         3          2  9960
# 3         4          2  7500
# 4         4          1  7420

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.15, random_state=1)


print("shape of training samples:",x_train.shape)
print("shape of test samples :", x_test.shape)
print("shape of train labels :", y_train.shape)
print("shape of test labels:",y_test.shape)
# Out:
# shape of training samples: (463, 3)
# shape of test samples : (82, 3)
# shape of train labels : (463,)
# shape of test labels: (82,)

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
lre=LinearRegression()

lre.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Intercept is ",lre.intercept_,"\n","Coefficients are",lre.coef_)
# Out:
# Intercept is  -98074.3503933344
#  Coefficients are [3.54878487e+05 1.53029836e+06 3.54850485e+02]

# %%
r_sq= lre.score(x_test, y_test)
print("R Square value is ",r_sq)
# Out:
# R Square value is  0.35116705286568883

# %%
y_pred = lre.predict(x_test)
print(f"predicted response:\n{y_pred}")
# Out:
# predicted response:
# [6596303.35711685 5832482.04054561 8107966.42450454 4774999.59225318
#  4844195.43688713 3419442.73630685 3291696.56159803 4838872.67960759
#  3100077.2995348  4271111.90312395 3437213.26266361 4546149.03132486
#  4200141.8060635  4164684.75962491 6759506.57826425 7015026.92977353
#  3660741.06631239 4271083.90103231 6724049.53182566 3436830.41008666
#  3355569.64895244 5978835.51059924 6845563.46790814 3625284.01987381
#  4949741.101131   5477603.55315169 3206532.44512548 7178230.15092093
#  6067548.13192481 3258013.76758596 6284006.9279592  6342557.25803407
#  4719116.28777617 4572734.81563088 5467667.73956322 3160401.88203619
#  6152740.250489   3094399.69176996 4342082.00018441 4739869.39420826
#  4611796.37110578 3731739.16546449 3635929.53443288 4608247.86625276
#  5633793.77086798 3685580.60028355 4217856.32823697 3706871.62940169
#  3029107.20247434 3863033.84502634 5155582.38469796 3618896.71113837
# ...

# %%
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y_test, y_pred)
RMSE = mean_squared_error(y_test, y_pred, squared=False)
print("MSE is:", MSE)
print("RMSE is:", RMSE)
print("R_squared is:", r_sq)
# Out:
# MSE is: 2674115521286.182
# RMSE is: 1635272.3079922139
# R_squared is: 0.35116705286568883

# %% [markdown]
# ## **Observation on the univariate model**

# %%
X = df['area']
y = df['price']

# %%
# calculate the slope and intercept of the best-fit line
slope = np.sum((X - np.mean(X)) * (y - np.mean(y))) / np.sum((X - np.mean(X)) ** 2)
intercept = np.mean(y) - slope * np.mean(X)

# %%
print(slope, intercept)
# Out:
# 461.9748942727835 2387308.48239643

# %%
lre=LinearRegression()
lre.fit(np.array(X).reshape((-1,1)),y)
pred_slope = lre.coef_
pred_intercept = lre.intercept_

# %%
print(pred_slope, pred_intercept)
# Out:
# [461.97489427] 2387308.48239643

# %%
# plot the scatter plot and the best-fit line
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.plot(X, slope * X + intercept, color='green')
plt.xlabel('area')
plt.ylabel('price')
plt.show()

# %%
# plot the scatter plot and the best-fit line
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.plot(X, slope * X + intercept, color='red')
plt.plot(X, pred_slope * X + pred_intercept, color='green')
plt.legend(['sample','actual','predicted'])
plt.xlabel('area')
plt.ylabel('price')
plt.show()
